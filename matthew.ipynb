# %% [markdown]
# <a href="https://colab.research.google.com/github/mwatkins1970/SpellGPT/blob/main/matthew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
GD_PATH = '/content/Drive'

from google.colab import drive
drive.mount(GD_PATH)
# Out:
# Mounted at /content/Drive

# %%
# !git clone https://github.com/mwatkins1970/alphabetical_probe
# Out:
# Cloning into 'alphabetical_probe'...
# remote: Enumerating objects: 612, done.
# remote: Counting objects: 100% (282/282), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 612 (delta 213), reused 256 (delta 190), pack-reused 330
# Receiving objects: 100% (612/612), 33.57 MiB | 34.97 MiB/s, done.
# Resolving deltas: 100% (487/487), done.

# %%
# %cd alphabetical_probe
# Out:
# /content/alphabetical_probe

# %%
# %ls
# Out:
# dev/    README.md         src/    to_be_sorted/  weights/
# myenv/  requirements.txt  tests/  wandb/

# %%
# %cd src
# %ls
# Out:
# /content/alphabetical_probe/src
# dataset.py                letter_token_utils.py  probe_training.py
# get_training_data.py      MLPs.py                probe_utils.py
# __init__.py               model_loading.py       token_utils.py
# length_probe_training.py  probes.py

# %%
# !python probes.py
# !python dataset.py
# !python MLPs.py

# %%
# !pip install transformers
# !pip install accelerate
# !pip install torch torchvision

# %%
import sys

sys.path.append('/content/alphabetical_probe')  # Adjust the path accordingly

import model_loading

# %%
tokenizer, GPTmodel, embeddings = model_loading.load_or_download_model_tok_emb()
